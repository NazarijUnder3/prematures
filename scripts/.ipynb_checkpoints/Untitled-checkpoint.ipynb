# %% [markdown]
# # level 1

# %%
a = 2 + 2
data.frame(a)
# Out:
#   a
# 1 4

# %% [markdown]
# Graph of sinus functgion

# %%
plot(seq(1, 100, 0.1), sin(seq(1, 100, 0.1)), 'l')
# Out:
# plot without title

# %% [markdown]
# ## level 2

# %% [raw]
# a = 2 + 2
# a
